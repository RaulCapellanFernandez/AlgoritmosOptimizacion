# %% [markdown]
# #### 2. Optimización escenas de doblaje:
#
# Se precisa coordinar el doblaje de una película. Los actores del doblaje deben coincidir en las
# tomas en las que sus personajes aparecen juntos en las diferentes tomas. Los actores de
# doblaje cobran todos la misma cantidad por cada día que deben desplazarse hasta el estudio de
# grabación independientemente del número de tomas que se graben. No es posible grabar más
# de 6 tomas por día. El objetivo es planificar las sesiones por día de manera que se gasto por los
# servicios de los actores de doblaje sea el menor posible.

# %%
import os.path
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
#Lee el excel
path = "./datosDoblaje.xlsx"
norm_path = os.path.normpath(path) 
datosDoblaje = pd.read_excel(norm_path)

# %% [markdown]
# ##### Primera solución -> Algoritmo Voraz
# No será la mejor solución pero nos proporcionará una buena primera solución

# %%
fila = datosDoblaje.loc[30]
fila.iloc[0] = 0
fila.iloc[-1] = 0
total = 0

for i in fila:
    if i > 0:
        total = total + int(i/6)+1
        print('Este actor necesita mínimo', (int(i/6)+1), 'dias')
total
# Out:
# Este actor necesita mínimo 4 dias
# Este actor necesita mínimo 3 dias
# Este actor necesita mínimo 3 dias
# Este actor necesita mínimo 3 dias
# Este actor necesita mínimo 2 dias
# Este actor necesita mínimo 2 dias
# Este actor necesita mínimo 1 dias
# Este actor necesita mínimo 1 dias
# Este actor necesita mínimo 1 dias
# Este actor necesita mínimo 1 dias
# 21

# %%
print(datosDoblaje.iloc[0]['ACT1'])

def optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion):
    if(escenas > 29):
        print('YA HEMOS ACABADO DE ORGANIZAR LAS ESCENAS')
    else:
        total = 0
        for i in range(actores):
            actorPos = 'ACT' + str(i+1)
            participacionesActor = matrizOcupacion[i][diaOrden]
            
            if(datosDoblaje.iloc[escena][actorPos]== 1):
                if(participacionesActor <= 6):
                    matrizOcupacion[i][diaOrden] = matrizOcupacion[i][diaOrden] + 1
                    total = total + 1
                    print('El dia',diaOrden,'El actor',actorPos,'puede trabajar en la escena',escena+1)
                    print('Este actor ha trabajado hoy en',matrizOcupacion[i][diaOrden],'escenas')
                else:
                    print('El dia',diaOrden,'El actor',actorPos,'NO puede trabajar en la escena',escena+1)
                    print('Este actor ha trabajado hoy en',matrizOcupacion[i][diaOrden],'escenas')
        if(total == datosDoblaje.iloc[escena]['Total']):
            print('////////////////////////////////////////////////////////////')
            print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
            print('////////////////////////////////////////////////////////////')
            optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
        else:
            print('**************************************************************')
            print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
            print('**************************************************************')
            optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
# Out:
# 1

# %%
diaOrden = 1
actores  = 10
escena  = 0

matrizOcupacion = np.zeros((10, 40))

optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
# Out:
# El dia 1 El actor ACT1 puede trabajar en la escena 1
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 1 El actor ACT2 puede trabajar en la escena 1
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 1 El actor ACT3 puede trabajar en la escena 1
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 1 El actor ACT4 puede trabajar en la escena 1
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 1 El actor ACT5 puede trabajar en la escena 1
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 1 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT3 puede trabajar en la escena 2
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 1 El actor ACT4 puede trabajar en la escena 2
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 1 El actor ACT5 puede trabajar en la escena 2
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 2 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT2 puede trabajar en la escena 3
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 1 El actor ACT5 puede trabajar en la escena 3
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 1 El actor ACT7 puede trabajar en la escena 3
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 3 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT1 puede trabajar en la escena 4
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 1 El actor ACT2 puede trabajar en la escena 4
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 1 El actor ACT7 puede trabajar en la escena 4
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 1 El actor ACT8 puede trabajar en la escena 4
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 4 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT2 puede trabajar en la escena 5
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 1 El actor ACT4 puede trabajar en la escena 5
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 1 El actor ACT8 puede trabajar en la escena 5
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 5 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT1 puede trabajar en la escena 6
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 1 El actor ACT2 puede trabajar en la escena 6
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 1 El actor ACT4 puede trabajar en la escena 6
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 1 El actor ACT5 puede trabajar en la escena 6
# Este actor ha trabajado hoy en 4.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 6 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT1 puede trabajar en la escena 7
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 1 El actor ACT2 puede trabajar en la escena 7
# Este actor ha trabajado hoy en 6.0 escenas
# El dia 1 El actor ACT4 puede trabajar en la escena 7
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 1 El actor ACT5 puede trabajar en la escena 7
# Este actor ha trabajado hoy en 5.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 7 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT1 puede trabajar en la escena 8
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 1 El actor ACT2 puede trabajar en la escena 8
# Este actor ha trabajado hoy en 7.0 escenas
# El dia 1 El actor ACT6 puede trabajar en la escena 8
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 8 se va a llevar a cabo el dia 1
# ////////////////////////////////////////////////////////////
# El dia 1 El actor ACT1 puede trabajar en la escena 9
# Este actor ha trabajado hoy en 6.0 escenas
# El dia 1 El actor ACT2 NO puede trabajar en la escena 9
# El dia 1 El actor ACT4 puede trabajar en la escena 9
# Este actor ha trabajado hoy en 6.0 escenas
# **************************************************************
# La escena 9 NO se va a llevar a cabo el dia 1
# **************************************************************
# El dia 2 El actor ACT1 puede trabajar en la escena 9
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 2 El actor ACT2 puede trabajar en la escena 9
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 2 El actor ACT4 puede trabajar en la escena 9
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 9 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 puede trabajar en la escena 10
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 2 El actor ACT2 puede trabajar en la escena 10
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 2 El actor ACT6 puede trabajar en la escena 10
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 2 El actor ACT9 puede trabajar en la escena 10
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 10 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 puede trabajar en la escena 11
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 2 El actor ACT2 puede trabajar en la escena 11
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 2 El actor ACT3 puede trabajar en la escena 11
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 2 El actor ACT5 puede trabajar en la escena 11
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 2 El actor ACT8 puede trabajar en la escena 11
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 11 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 puede trabajar en la escena 12
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 2 El actor ACT2 puede trabajar en la escena 12
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 2 El actor ACT3 puede trabajar en la escena 12
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 2 El actor ACT4 puede trabajar en la escena 12
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 2 El actor ACT6 puede trabajar en la escena 12
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 12 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 puede trabajar en la escena 13
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 2 El actor ACT4 puede trabajar en la escena 13
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 2 El actor ACT5 puede trabajar en la escena 13
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 13 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 puede trabajar en la escena 14
# Este actor ha trabajado hoy en 6.0 escenas
# El dia 2 El actor ACT3 puede trabajar en la escena 14
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 2 El actor ACT6 puede trabajar en la escena 14
# Este actor ha trabajado hoy en 3.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 14 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 puede trabajar en la escena 15
# Este actor ha trabajado hoy en 7.0 escenas
# El dia 2 El actor ACT2 puede trabajar en la escena 15
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 2 El actor ACT7 puede trabajar en la escena 15
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 15 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT4 puede trabajar en la escena 16
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 2 El actor ACT10 puede trabajar en la escena 16
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 16 se va a llevar a cabo el dia 2
# ////////////////////////////////////////////////////////////
# El dia 2 El actor ACT1 NO puede trabajar en la escena 17
# El dia 2 El actor ACT3 puede trabajar en la escena 17
# Este actor ha trabajado hoy en 4.0 escenas
# **************************************************************
# La escena 17 NO se va a llevar a cabo el dia 2
# **************************************************************
# El dia 3 El actor ACT1 puede trabajar en la escena 17
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 3 El actor ACT3 puede trabajar en la escena 17
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 17 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT3 puede trabajar en la escena 18
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 3 El actor ACT6 puede trabajar en la escena 18
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 18 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT1 puede trabajar en la escena 19
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 3 El actor ACT3 puede trabajar en la escena 19
# Este actor ha trabajado hoy en 3.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 19 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT1 puede trabajar en la escena 20
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 3 El actor ACT3 puede trabajar en la escena 20
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 3 El actor ACT4 puede trabajar en la escena 20
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 3 El actor ACT5 puede trabajar en la escena 20
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 20 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT6 puede trabajar en la escena 21
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 3 El actor ACT8 puede trabajar en la escena 21
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 21 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT1 puede trabajar en la escena 22
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 3 El actor ACT2 puede trabajar en la escena 22
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 3 El actor ACT3 puede trabajar en la escena 22
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 3 El actor ACT4 puede trabajar en la escena 22
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 22 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT1 puede trabajar en la escena 23
# Este actor ha trabajado hoy en 5.0 escenas
# El dia 3 El actor ACT3 puede trabajar en la escena 23
# Este actor ha trabajado hoy en 6.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 23 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT3 puede trabajar en la escena 24
# Este actor ha trabajado hoy en 7.0 escenas
# El dia 3 El actor ACT6 puede trabajar en la escena 24
# Este actor ha trabajado hoy en 3.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 24 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT1 puede trabajar en la escena 25
# Este actor ha trabajado hoy en 6.0 escenas
# El dia 3 El actor ACT2 puede trabajar en la escena 25
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 3 El actor ACT4 puede trabajar en la escena 25
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 3 El actor ACT10 puede trabajar en la escena 25
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 25 se va a llevar a cabo el dia 3
# ////////////////////////////////////////////////////////////
# El dia 3 El actor ACT1 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 7.0 escenas
# El dia 3 El actor ACT3 NO puede trabajar en la escena 26
# El dia 3 El actor ACT5 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 3 El actor ACT9 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 1.0 escenas
# **************************************************************
# La escena 26 NO se va a llevar a cabo el dia 3
# **************************************************************
# El dia 4 El actor ACT1 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 4 El actor ACT3 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 4 El actor ACT5 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 4 El actor ACT9 puede trabajar en la escena 26
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 26 se va a llevar a cabo el dia 4
# ////////////////////////////////////////////////////////////
# El dia 4 El actor ACT4 puede trabajar en la escena 27
# Este actor ha trabajado hoy en 1.0 escenas
# El dia 4 El actor ACT5 puede trabajar en la escena 27
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 27 se va a llevar a cabo el dia 4
# ////////////////////////////////////////////////////////////
# El dia 4 El actor ACT1 puede trabajar en la escena 28
# Este actor ha trabajado hoy en 2.0 escenas
# El dia 4 El actor ACT4 puede trabajar en la escena 28
# Este actor ha trabajado hoy en 2.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 28 se va a llevar a cabo el dia 4
# ////////////////////////////////////////////////////////////
# El dia 4 El actor ACT1 puede trabajar en la escena 29
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 4 El actor ACT5 puede trabajar en la escena 29
# Este actor ha trabajado hoy en 3.0 escenas
# El dia 4 El actor ACT6 puede trabajar en la escena 29
# Este actor ha trabajado hoy en 1.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 29 se va a llevar a cabo el dia 4
# ////////////////////////////////////////////////////////////
# El dia 4 El actor ACT1 puede trabajar en la escena 30
# Este actor ha trabajado hoy en 4.0 escenas
# El dia 4 El actor ACT4 puede trabajar en la escena 30
# Este actor ha trabajado hoy en 3.0 escenas
# ////////////////////////////////////////////////////////////
# La escena 30 se va a llevar a cabo el dia 4
# ////////////////////////////////////////////////////////////
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 4
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 5
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 6
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 7
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 8
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 9
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 10
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 11
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 12
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 13
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 14
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 15
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 16
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 17
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 18
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 19
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 20
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 21
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 22
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 23
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 24
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 25
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 26
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 27
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 28
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 29
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 30
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 31
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 32
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 33
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 34
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 35
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 36
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 37
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 38
# **************************************************************
# **************************************************************
# La escena 31 NO se va a llevar a cabo el dia 39
# **************************************************************
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-48b82741be20> in <module>
#       5 matrizOcupacion = np.zeros((10, 40))
#       6
# ----> 7 optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      22             print('La escena',escena+1,'se va a llevar a cabo el dia',diaOrden)
#      23             print('////////////////////////////////////////////////////////////')
# ---> 24             optimizaOrdenDoblaje(diaOrden, actores, escena+1, matrizOcupacion)
#      25         else:
#      26             print('**************************************************************')
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#      27             print('La escena',escena+1,'NO se va a llevar a cabo el dia',diaOrden)
#      28             print('**************************************************************')
# ---> 29             optimizaOrdenDoblaje(diaOrden+1, actores, escena, matrizOcupacion)
#
# <ipython-input-87-b9f78d484644> in optimizaOrdenDoblaje(diaOrden, actores, escena, matrizOcupacion)
#       8         for i in range(actores):
#       9             actorPos = 'ACT' + str(i+1)
# ---> 10             participacionesActor = matrizOcupacion[i][diaOrden]
#      11
#      12             if(datosDoblaje.iloc[escena][actorPos]== 1):
#
# IndexError: index 40 is out of bounds for axis 0 with size 40

# %% [markdown]
# #### Segunda solución -> Algoritmos evolutivos??

# %% [markdown]
# #### Segunda solución -> Algoritmos Heurísticos
